# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

def get_stats(detected_faces):
    recognized_faces = detected_faces[(detected_faces['gender'] == 'Male') | (detected_faces['gender'] == 'Female')]
    men_pc = float((recognized_faces['gender'] == 'Male').sum()) / recognized_faces.shape[0]
    ages = recognized_faces.groupby('person_id')['age'].mean()

    # percentage of interested faces in frames
    interested_pc = (np.array(detected_faces[['frame', 'interest']].groupby('frame').sum()['interest'], dtype=float) /
                     np.array(detected_faces[['frame', 'interest']].groupby('frame').size()) * 100)
    
    interested_pc = (np.array(detected_faces[['frame', 'interest']].groupby('frame').sum()['interest'], dtype=float) /
                     len(np.unique(faces_df['person_id']))) * 100
    
    interested_pc = (np.array(detected_faces[['frame', 'interest']].groupby('frame').sum()['interest'], dtype=float) /
                     np.median(pd.DataFrame(np.array(detected_faces.groupby('frame').size())))) * 100

    smoothed_interest = pd.ewma(interested_pc, alpha=0.03)
    frames_id = np.unique(detected_faces['frame'])
    return men_pc, ages, frames_id, smoothed_interest

# %%
file = '/Users/dwalter/2017_0307_140932_012-data.csv'

# %%
faces_df = pd.read_csv(file)

# %%
men_pc, ages, frames_id, smoothed_interest = get_stats(faces_df)
# Out:
# /usr/local/lib/python2.7/site-packages/ipykernel/__main__.py:21: FutureWarning: pd.ewm_mean is deprecated for ndarrays and will be removed in a future version

# %%
plt.figure(figsize=(9,4))
plt.plot(smoothed_interest)

# %%
plt.figure(figsize=(9,4))
plt.plot(smoothed_interest)

# %%
plt.figure(figsize=(9,4))
plt.plot(smoothed_interest)

# %%
plt.figure(figsize=(9,4))
plt.plot(smoothed_interest)

# %%
len(np.unique(faces_df['person_id']))
# Out:
# 242

# %%
plt.figure(figsize=(9,4))
plt.plot(frames_id, smoothed_interest)

# %%
np.mean(pd.DataFrame(np.array(faces_df.groupby('frame').size())))
# Out:
# 0    48.27725
# dtype: float64

# %%
plt.figure(figsize=(9,4))
plt.plot(frames_id, smoothed_interest)

# %%
plt.figure(figsize=(9,4))
plt.plot(frames_id, smoothed_interest)

# %%
np.median(pd.DataFrame(np.array(faces_df.groupby('frame').size())))
# Out:
# 49.0

# %%
filename = '/Users/dwalter/Примеры запусков/Yandex/00001-data.csv'
faces_df = pd.read_csv(filename)
men_pc, ages, frames_id, smoothed_interest = get_stats(faces_df)
# Out:
# /usr/local/lib/python2.7/site-packages/ipykernel/__main__.py:21: FutureWarning: pd.ewm_mean is deprecated for ndarrays and will be removed in a future version

# %%
plt.figure(figsize=(9,4))
plt.plot(frames_id, smoothed_interest)

# %%
plt.figure(figsize=(9,4))
plt.plot(frames_id, smoothed_interest)

# %%
men_pc, ages, frames_id, smoothed_interest = get_stats(faces_df)
plt.figure(figsize=(9,4))
plt.plot(frames_id, smoothed_interest)
# Out:
# /usr/local/lib/python2.7/site-packages/ipykernel/__main__.py:21: FutureWarning: pd.ewm_mean is deprecated for ndarrays and will be removed in a future version

# %%
men_pc, ages, frames_id, smoothed_interest = get_stats(faces_df)
plt.figure(figsize=(9,4))
plt.plot(frames_id, smoothed_interest)
# Out:
# /usr/local/lib/python2.7/site-packages/ipykernel/__main__.py:21: FutureWarning: pd.ewm_mean is deprecated for ndarrays and will be removed in a future version

# %%
plt.plot(pd.DataFrame(np.array(faces_df.groupby('frame').size())))

# %%
np.median(pd.DataFrame(np.array(faces_df.groupby('frame').size())))
# Out:
# 93.0

# %%
faces_df
# Out:
#         Unnamed: 0   frame  person_id            x           y          w  \
# 0                0     0.0        1.0   118.582171  347.809418  27.730103
# 1                1     0.0        2.0   148.745359  320.516442  23.671447
# 2                2     0.0        3.0   191.085210  270.626367  20.582879
# 3                3     0.0        4.0  1866.766873  159.348271  27.638572
# 4                4     0.0        5.0  1441.661988  196.585278  23.754147
# 5                5     0.0        6.0  1643.609465  271.070705  33.035605
# 6                6     0.0        7.0  1450.092445  448.253371  41.093340
# 7                7     0.0        8.0   966.763533  346.023569  32.492786
# 8                8     0.0        9.0  1358.814496  263.587806  31.885164
# 9                9     0.0       10.0   550.637938  367.931964  27.233234
# 10              10     0.0       11.0   840.237001  429.159842  35.033749
# 11              11     0.0       12.0   723.208212  412.500473  29.731031
# ...

# %%
faces_df.groupby('interest')
# Out:
# 219

# %%
plt.figure(figsize=[10, 5])
plt.scatter(faces_df[faces_df['person_id'] == np.unique(faces_df["person_id"])[0]]["frame"],
            faces_df[faces_df['person_id'] == np.unique(faces_df["person_id"])[0]]['interest'])
plt.scatter(faces_df[faces_df['person_id'] == np.unique(faces_df["person_id"])[1]]["frame"],
            faces_df[faces_df['person_id'] == np.unique(faces_df["person_id"])[1]]['interest'], color='r')
plt.scatter(faces_df[faces_df['person_id'] == np.unique(faces_df["person_id"])[2]]["frame"],
            faces_df[faces_df['person_id'] == np.unique(faces_df["person_id"])[2]]['interest'])
